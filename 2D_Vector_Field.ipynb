# %% [markdown]
# ## 2D Vector Field
# This image shows a 2D vector field, where each point has both a direction and a magnitude, often visualized with arrows.

# %%
from IPython.display import Image, display
display(Image(filename="prob3_vector2d.png"))
