# %% [markdown]
# ## 1D Time Series
# This image shows a time series where a single value changes over time.

# %%
from IPython.display import Image, display

display(Image(filename="prob3_ts_1d.png"))
