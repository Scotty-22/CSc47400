# %% [markdown]
# ## 3D Scalar Field
# This image shows a scalar field in 3D, where each point in space (x, y, z) has one scalar value, represented by color or intensity.

# %%
from IPython.display import Image, display
display(Image(filename="prob3_scalar3d.png"))
