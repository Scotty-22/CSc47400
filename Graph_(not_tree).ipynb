# %% [markdown]
# ## Graph (Not Tree)
# This image shows a **graph**, where nodes are connected by edges.
# It is not a tree because there are cycles (for example A–C–D–B–A).

# %%
from IPython.display import Image, display
display(Image(filename="prob3_graph.png"))
