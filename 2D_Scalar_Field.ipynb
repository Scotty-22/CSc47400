# %% [markdown]
# ## 2D Scalar Field
# This image shows a scalar field where each point in 2D (x, y) has one value represented by color.

# %%
from IPython.display import Image, display
display(Image(filename="prob3_scalar2d.png"))
