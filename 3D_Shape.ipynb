# %% [markdown]
# ## 3D Scalar Field
# This image shows a 3D scalar field where each point \((x,y)\) has one scalar value \(z\). The surface height and color represent the scalar value.

# %%
from IPython.display import Image, display
display(Image(filename="prob3_scalar3d.png"))
